# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalmunai
# Processing Record 2 of Set 1 | asau
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | wuda
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | awbari
# Processing Record 16 of Set 1 | matara
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | leh
# Processing Record 19 of Set 1 | vila do maio
# Processing Record 20 of Set 1 | zavodouspenskoye
# Processing Record 21 of Set 1 | borbon
# Processing Record 22 of Set 1 | luganville
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | komsomolskiy
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | key largo
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | povenets
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | ambon
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | bourail
# Processing Record 39 of Set 1 | volosovo
# Processing Record 40 of Set 1 | sapa
# Processing Record 41 of Set 1 | conde
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | maningrida
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | salina cruz
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | casablanca
# Processing Record 0 of Set 2 | pevek
# Processing Record 1 of Set 2 | walla walla
# Processing Record 2 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | kataysk
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | takoradi
# Processing Record 10 of Set 2 | jiehu
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 2 | ucluelet
# Processing Record 17 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | trinidad
# Processing Record 20 of Set 2 | tura
# Processing Record 21 of Set 2 | yerbogachen
# Processing Record 22 of Set 2 | jesup
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | senador guiomard
# Processing Record 27 of Set 2 | port lincoln
# Processing Record 28 of Set 2 | kandrian
# Processing Record 29 of Set 2 | montepuez
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | bagarji
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | honiara
# Processing Record 34 of Set 2 | kavaratti
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | boysun
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | korla
# Processing Record 45 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 2 | vanimo
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | davila
# Processing Record 49 of Set 2 | ola
# Processing Record 0 of Set 3 | puerto ayora
# Processing Record 1 of Set 3 | chute-aux-outardes
# Processing Record 2 of Set 3 | amahai
# Processing Record 3 of Set 3 | vilcun
# Processing Record 4 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | tateyama
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | palauig
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | gorontalo
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | bonthe
# Processing Record 14 of Set 3 | tigil
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | estelle
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | sovetskiy
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | katunino
# Processing Record 23 of Set 3 | westerland
# Processing Record 24 of Set 3 | acapulco
# Processing Record 25 of Set 3 | barroualie
# City not found. Skipping...
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | waingapu
# Processing Record 30 of Set 3 | vestmannaeyjar
# Processing Record 31 of Set 3 | qaqortoq
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | sambava
# Processing Record 34 of Set 3 | riyadh
# Processing Record 35 of Set 3 | ushuaia
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | palora
# Processing Record 38 of Set 3 | elko
# Processing Record 39 of Set 3 | monterey
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | chernyshkovskiy
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | camacha
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | kemijarvi
# Processing Record 47 of Set 3 | omurtag
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | saint george
# Processing Record 0 of Set 4 | lorengau
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 4 | bandarbeyla
# Processing Record 4 of Set 4 | maarianhamina
# Processing Record 5 of Set 4 | san ramon
# Processing Record 6 of Set 4 | itarema
# Processing Record 7 of Set 4 | port augusta
# Processing Record 8 of Set 4 | qasigiannguit
# Processing Record 9 of Set 4 | puerto escondido
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | kamwenge
# Processing Record 14 of Set 4 | montecristo
# Processing Record 15 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | sondershausen
# Processing Record 18 of Set 4 | coihaique
# Processing Record 19 of Set 4 | baryshivka
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | fukue
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | sobolevo
# Processing Record 27 of Set 4 | pathardi
# Processing Record 28 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 4 | doha
# Processing Record 30 of Set 4 | yaan
# Processing Record 31 of Set 4 | pitiquito
# Processing Record 32 of Set 4 | araouane
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | muli
# Processing Record 36 of Set 4 | hambantota
# Processing Record 37 of Set 4 | gornyy
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | myaundzha
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | marzuq
# Processing Record 42 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 43 of Set 4 | solnechnyy
# Processing Record 44 of Set 4 | mwinilunga
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | ilulissat
# Processing Record 48 of Set 4 | bosaso
# Processing Record 49 of Set 4 | angoche
# Processing Record 0 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | konibodom
# Processing Record 2 of Set 5 | mosquera
# Processing Record 3 of Set 5 | makubetsu
# Processing Record 4 of Set 5 | burnie
# Processing Record 5 of Set 5 | cristalina
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | san juan
# Processing Record 11 of Set 5 | hammerfest
# Processing Record 12 of Set 5 | chihuahua
# Processing Record 13 of Set 5 | bud
# Processing Record 14 of Set 5 | konitsa
# Processing Record 15 of Set 5 | dagda
# Processing Record 16 of Set 5 | sasaram
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | saint anthony
# Processing Record 21 of Set 5 | pemba
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 5 | beloha
# Processing Record 26 of Set 5 | aksha
# Processing Record 27 of Set 5 | ginir
# Processing Record 28 of Set 5 | el paujil
# Processing Record 29 of Set 5 | rancagua
# Processing Record 30 of Set 5 | tiksi
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | say
# Processing Record 33 of Set 5 | mumford
# Processing Record 34 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 5 | sakakah
# Processing Record 36 of Set 5 | vuktyl
# Processing Record 37 of Set 5 | ende
# Processing Record 38 of Set 5 | imbituba
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | birjand
# Processing Record 41 of Set 5 | kirovskiy
# Processing Record 42 of Set 5 | labuhan
# Processing Record 43 of Set 5 | tiznit
# Processing Record 44 of Set 5 | batagay-alyta
# Processing Record 45 of Set 5 | carnduff
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | vanavara
# Processing Record 48 of Set 5 | iquique
# Processing Record 49 of Set 5 | tual
# Processing Record 0 of Set 6 | lebu
# Processing Record 1 of Set 6 | mustasaari
# Processing Record 2 of Set 6 | zhezkazgan
# Processing Record 3 of Set 6 | naliya
# Processing Record 4 of Set 6 | smolenka
# Processing Record 5 of Set 6 | los llanos de aridane
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | nago
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | puerto del rosario
# Processing Record 11 of Set 6 | blairmore
# Processing Record 12 of Set 6 | mareeba
# Processing Record 13 of Set 6 | port-gentil
# Processing Record 14 of Set 6 | ormara
# Processing Record 15 of Set 6 | vostok
# Processing Record 16 of Set 6 | evensk
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | kaohsiung
# Processing Record 20 of Set 6 | douentza
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | naze
# Processing Record 23 of Set 6 | cayeli
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | dunmore town
# Processing Record 27 of Set 6 | talakan
# Processing Record 28 of Set 6 | cajamarca
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | bilma
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | mar del plata
# Processing Record 33 of Set 6 | kiunga
# Processing Record 34 of Set 6 | visnes
# Processing Record 35 of Set 6 | coruripe
# Processing Record 36 of Set 6 | kenai
# Processing Record 37 of Set 6 | cabo rojo
# Processing Record 38 of Set 6 | wuzhou
# Processing Record 39 of Set 6 | irece
# Processing Record 40 of Set 6 | ilam
# Processing Record 41 of Set 6 | luderitz
# Processing Record 42 of Set 6 | manaure
# Processing Record 43 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | kupang
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | marabba
# Processing Record 48 of Set 6 | eyl
# Processing Record 49 of Set 6 | andenes
# Processing Record 0 of Set 7 | moissala
# Processing Record 1 of Set 7 | atasu
# Processing Record 2 of Set 7 | guilin
# Processing Record 3 of Set 7 | codrington
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | robertsganj
# Processing Record 6 of Set 7 | nieuw amsterdam
# Processing Record 7 of Set 7 | pavilosta
# Processing Record 8 of Set 7 | muhos
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | male
# Processing Record 11 of Set 7 | xining
# Processing Record 12 of Set 7 | soledar
# Processing Record 13 of Set 7 | troitskoye
# Processing Record 14 of Set 7 | ambilobe
# Processing Record 15 of Set 7 | sinnamary
# Processing Record 16 of Set 7 | dayong
# Processing Record 17 of Set 7 | ankpa
# Processing Record 18 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 7 | kalengwa
# Processing Record 20 of Set 7 | artyom
# Processing Record 21 of Set 7 | teguldet
# Processing Record 22 of Set 7 | shakawe
# Processing Record 23 of Set 7 | raja sansi
# Processing Record 24 of Set 7 | bac lieu
# Processing Record 25 of Set 7 | bubaque
# Processing Record 26 of Set 7 | ardesen
# Processing Record 27 of Set 7 | okahandja
# Processing Record 28 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | baykit
# Processing Record 31 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 7 | altay
# Processing Record 33 of Set 7 | pedernales
# Processing Record 34 of Set 7 | severo-yeniseyskiy
# Processing Record 35 of Set 7 | belaya gora
# Processing Record 36 of Set 7 | puke
# Processing Record 37 of Set 7 | nushki
# Processing Record 38 of Set 7 | cacu
# Processing Record 39 of Set 7 | berlevag
# Processing Record 40 of Set 7 | namatanai
# Processing Record 41 of Set 7 | narsaq
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | dali
# Processing Record 44 of Set 7 | atikokan
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | broome
# Processing Record 47 of Set 7 | pionerskiy
# Processing Record 48 of Set 7 | port blair
# Processing Record 49 of Set 7 | kuppam
# Processing Record 0 of Set 8 | roebourne
# Processing Record 1 of Set 8 | vigrestad
# Processing Record 2 of Set 8 | tromso
# Processing Record 3 of Set 8 | severodvinsk
# Processing Record 4 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 8 | isangel
# Processing Record 6 of Set 8 | maryville
# Processing Record 7 of Set 8 | cherskiy
# Processing Record 8 of Set 8 | akyab
# Processing Record 9 of Set 8 | purwakarta
# Processing Record 10 of Set 8 | xai-xai
# Processing Record 11 of Set 8 | port hawkesbury
# Processing Record 12 of Set 8 | mecca
# Processing Record 13 of Set 8 | jiupu
# Processing Record 14 of Set 8 | camocim
# Processing Record 15 of Set 8 | anadyr
# Processing Record 16 of Set 8 | clarksburg
# Processing Record 17 of Set 8 | kerema
# Processing Record 18 of Set 8 | coos bay
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | steinbach
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | wyndham
# Processing Record 25 of Set 8 | aktau
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | santa helena de goias
# Processing Record 28 of Set 8 | chilca
# Processing Record 29 of Set 8 | cassilandia
# Processing Record 30 of Set 8 | rognan
# Processing Record 31 of Set 8 | sarangani
# Processing Record 32 of Set 8 | zaozerne
# Processing Record 33 of Set 8 | linhares
# Processing Record 34 of Set 8 | belle fourche
# Processing Record 35 of Set 8 | ballina
# Processing Record 36 of Set 8 | sembakung
# Processing Record 37 of Set 8 | atar
# Processing Record 38 of Set 8 | grand forks
# Processing Record 39 of Set 8 | samana
# Processing Record 40 of Set 8 | nabire
# Processing Record 41 of Set 8 | am timan
# Processing Record 42 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 8 | popondetta
# Processing Record 44 of Set 8 | griffith
# Processing Record 45 of Set 8 | geraldton
# Processing Record 46 of Set 8 | fagerstrand
# Processing Record 47 of Set 8 | yuzhno-kurilsk
# Processing Record 48 of Set 8 | chaman
# Processing Record 49 of Set 8 | east wenatchee bench
# Processing Record 0 of Set 9 | artigas
# Processing Record 1 of Set 9 | portlethen
# Processing Record 2 of Set 9 | cayenne
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | merrill
# Processing Record 6 of Set 9 | miramar
# Processing Record 7 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 9 | leningradskiy
# Processing Record 9 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 9 | batelov
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | yabrud
# Processing Record 13 of Set 9 | lhokseumawe
# Processing Record 14 of Set 9 | kahului
# Processing Record 15 of Set 9 | zhuanghe
# Processing Record 16 of Set 9 | poya
# Processing Record 17 of Set 9 | lewistown
# Processing Record 18 of Set 9 | novyy urengoy
# Processing Record 19 of Set 9 | worland
# Processing Record 20 of Set 9 | xixiang
# Processing Record 21 of Set 9 | meadow lake
# Processing Record 22 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | iralaya
# Processing Record 24 of Set 9 | egvekinot
# Processing Record 25 of Set 9 | kutum
# Processing Record 26 of Set 9 | tulsipur
# Processing Record 27 of Set 9 | arroyohondo
# Processing Record 28 of Set 9 | vangaindrano
# Processing Record 29 of Set 9 | rubizhne
# Processing Record 30 of Set 9 | gardez
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | porto santo
# Processing Record 33 of Set 9 | ketchikan
# Processing Record 34 of Set 9 | mirnyy
# Processing Record 35 of Set 9 | jacmel
# Processing Record 36 of Set 9 | hirson
# Processing Record 37 of Set 9 | zarubino
# Processing Record 38 of Set 9 | damara
# Processing Record 39 of Set 9 | meulaboh
# Processing Record 40 of Set 9 | vila
# Processing Record 41 of Set 9 | ayer itam
# City not found. Skipping...
# Processing Record 42 of Set 9 | salinopolis
# Processing Record 43 of Set 9 | derzhavinsk
# Processing Record 44 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | ajdabiya
# Processing Record 47 of Set 9 | yemelyanovo
# Processing Record 48 of Set 9 | jumla
# Processing Record 49 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 0 of Set 10 | port keats
# Processing Record 1 of Set 10 | lokosovo
# Processing Record 2 of Set 10 | pedasi
# Processing Record 3 of Set 10 | karratha
# Processing Record 4 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 10 | egra
# Processing Record 6 of Set 10 | bad doberan
# Processing Record 7 of Set 10 | san juan bautista
# Processing Record 8 of Set 10 | tilichiki
# Processing Record 9 of Set 10 | farmington
# Processing Record 10 of Set 10 | arrentela
# Processing Record 11 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | hobyo
# Processing Record 13 of Set 10 | dabhol
# Processing Record 14 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 10 | rosignol
# Processing Record 16 of Set 10 | shikhazany
# Processing Record 17 of Set 10 | turiacu
# Processing Record 18 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 10 | teguise
# Processing Record 20 of Set 10 | axim
# Processing Record 21 of Set 10 | rio grande
# Processing Record 22 of Set 10 | pozo colorado
# Processing Record 23 of Set 10 | bonavista
# Processing Record 24 of Set 10 | aklavik
# Processing Record 25 of Set 10 | gizo
# Processing Record 26 of Set 10 | emba
# Processing Record 27 of Set 10 | niltepec
# Processing Record 28 of Set 10 | oum hadjer
# Processing Record 29 of Set 10 | channel-port aux basques
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | dolinsk
# Processing Record 32 of Set 10 | nanchang
# Processing Record 33 of Set 10 | olafsvik
# Processing Record 34 of Set 10 | northam
# Processing Record 35 of Set 10 | aykhal
# Processing Record 36 of Set 10 | verkhnevilyuysk
# Processing Record 37 of Set 10 | puerto carreno
# Processing Record 38 of Set 10 | camargo
# Processing Record 39 of Set 10 | aldan
# Processing Record 40 of Set 10 | chiang khong
# Processing Record 41 of Set 10 | chernyshevskiy
# Processing Record 42 of Set 10 | mogadishu
# Processing Record 43 of Set 10 | santa isabel do rio negro
# Processing Record 44 of Set 10 | knysna
# Processing Record 45 of Set 10 | riachao do dantas
# Processing Record 46 of Set 10 | sayat
# Processing Record 47 of Set 10 | lobva
# Processing Record 48 of Set 10 | turinsk
# Processing Record 49 of Set 10 | kungurtug
# Processing Record 0 of Set 11 | rantepao
# Processing Record 1 of Set 11 | ambovombe
# Processing Record 2 of Set 11 | esso
# Processing Record 3 of Set 11 | fortuna
# Processing Record 4 of Set 11 | fort walton beach
# Processing Record 5 of Set 11 | maraa
# Processing Record 6 of Set 11 | iranshahr
# Processing Record 7 of Set 11 | paamiut
# Processing Record 8 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 11 | traverse city
# Processing Record 10 of Set 11 | zheleznodorozhnyy
# Processing Record 11 of Set 11 | kirakira
# Processing Record 12 of Set 11 | alta floresta
# Processing Record 13 of Set 11 | yenagoa
# Processing Record 14 of Set 11 | ilyich
# Processing Record 15 of Set 11 | hualmay
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | bantry
# Processing Record 18 of Set 11 | kamaishi
# Processing Record 19 of Set 11 | kumo
# Processing Record 20 of Set 11 | denpasar
# Processing Record 21 of Set 11 | svetlogorsk
# Processing Record 22 of Set 11 | homer
# Processing Record 23 of Set 11 | ayan
# Processing Record 24 of Set 11 | ramjibanpur
# Processing Record 25 of Set 11 | san jeronimo
# Processing Record 26 of Set 11 | orcopampa
# Processing Record 27 of Set 11 | provideniya
# Processing Record 28 of Set 11 | porto novo
# Processing Record 29 of Set 11 | nhulunbuy
# Processing Record 30 of Set 11 | san quintin
# Processing Record 31 of Set 11 | volchansk
# Processing Record 32 of Set 11 | khandyga
# Processing Record 33 of Set 11 | rio gallegos
# Processing Record 34 of Set 11 | roswell
# Processing Record 35 of Set 11 | huarmey
# Processing Record 36 of Set 11 | chake chake
# Processing Record 37 of Set 11 | medyn
# Processing Record 38 of Set 11 | fenoarivo atsinanana
# Processing Record 39 of Set 11 | tripoli
# Processing Record 40 of Set 11 | anori
# Processing Record 41 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 11 | karakol
# Processing Record 43 of Set 11 | wukari
# Processing Record 44 of Set 11 | ewa beach
# Processing Record 45 of Set 11 | belozerskoye
# Processing Record 46 of Set 11 | french harbor
# Processing Record 47 of Set 11 | lompoc
# Processing Record 48 of Set 11 | manjeshwar
# Processing Record 49 of Set 11 | loandjili
# Processing Record 0 of Set 12 | harper
# Processing Record 1 of Set 12 | chara
# Processing Record 2 of Set 12 | grafton
# Processing Record 3 of Set 12 | kyren
# Processing Record 4 of Set 12 | calabozo
# Processing Record 5 of Set 12 | muros
# Processing Record 6 of Set 12 | bacolod
# Processing Record 7 of Set 12 | guaruja
# Processing Record 8 of Set 12 | buala
# Processing Record 9 of Set 12 | tupik
# Processing Record 10 of Set 12 | mackenzie
# Processing Record 11 of Set 12 | husavik
# Processing Record 12 of Set 12 | mehamn
# Processing Record 13 of Set 12 | lucapa
# Processing Record 14 of Set 12 | cabra
# Processing Record 15 of Set 12 | pahrump
# Processing Record 16 of Set 12 | yumen
# Processing Record 17 of Set 12 | bousso
# Processing Record 18 of Set 12 | mikkeli
# Processing Record 19 of Set 12 | miles city
# Processing Record 20 of Set 12 | tefe
# Processing Record 21 of Set 12 | college
# Processing Record 22 of Set 12 | kretinga
# Processing Record 23 of Set 12 | truro
# Processing Record 24 of Set 12 | chifeng
# Processing Record 25 of Set 12 | binzhou
# Processing Record 26 of Set 12 | aloleng
# Processing Record 27 of Set 12 | antofagasta
# Processing Record 28 of Set 12 | hudson bay
# Processing Record 29 of Set 12 | alice springs
# Processing Record 30 of Set 12 | kurbnesh
# Processing Record 31 of Set 12 | orlik
# Processing Record 32 of Set 12 | ordynskoye
# Processing Record 33 of Set 12 | zhanaozen
# Processing Record 34 of Set 12 | torres
# Processing Record 35 of Set 12 | deep river
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | kasongo-lunda
# Processing Record 38 of Set 12 | yaransk
# Processing Record 39 of Set 12 | plettenberg bay
# Processing Record 40 of Set 12 | shimsk
# Processing Record 41 of Set 12 | norfolk
# Processing Record 42 of Set 12 | concarneau
# Processing Record 43 of Set 12 | waipawa
# Processing Record 44 of Set 12 | laksham
# Processing Record 45 of Set 12 | new bedford
# Processing Record 46 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 48 of Set 12 | baikunthpur
# Processing Record 49 of Set 12 | tezu
# Processing Record 0 of Set 13 | rakamaz
# Processing Record 1 of Set 13 | porbandar
# Processing Record 2 of Set 13 | carmen
# Processing Record 3 of Set 13 | san andres
# Processing Record 4 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 13 | krasnoselkup
# Processing Record 6 of Set 13 | golkoy
# Processing Record 7 of Set 13 | kadaya
# Processing Record 8 of Set 13 | prince albert
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#placing json data into a data frame

city_data_pd = pd.DataFrame(city_data)

#displaying the top of the data frame
city_data_pd.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   kalmunai   7.4167   81.8167     77.94        81          62        5.01
# 1       asau  46.4333   26.4000     39.99        45           1        3.47
# 2     faanui -16.4833 -151.7500     82.27        70          59        9.60
# 3  jamestown  42.0970  -79.2353     73.40        27           1       10.36
# 4   hermanus -34.4187   19.2345     60.01        92         100        2.93
#
#   Country        Date
# 0      LK  1618095113
# 1      RO  1618095113
# 2      PF  1618095113
# 3      US  1618095113
# 4      ZA  1618095114

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# inspecting the data frame
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    22.637758   20.568249   56.659357   70.882143   52.783929    8.206000
# std     32.867285   90.340660   24.439260   22.273878   39.239844    5.348714
# min    -54.800000 -179.166700  -16.740000    5.000000    0.000000    0.200000
# 25%     -3.779700  -59.974650   39.200000   61.000000   12.000000    4.155000
# 50%     27.836350   24.548000   62.885000   75.500000   57.000000    6.930000
# 75%     50.420600   99.914575   77.450000   87.000000   92.000000   11.160000
# max     78.218600  179.316700   93.000000  100.000000  100.000000   28.990000
#
#                Date
# count  5.600000e+02
# mean   1.618095e+09
# std    7.065538e+01
# min    1.618095e+09
# 25%    1.618095e+09
# 50%    1.618095e+09
# 75%    1.618095e+09
# max    1.618095e+09

# %%
#  Get the indices of cities that have humidity over 100%.

#Based on the describe function, there are no cities in this data set that have a humidity over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Based on the describe function, there are no cities in this data set that have a humidity over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
